# %% [markdown]
# # Oppgaver med punkt og linjer

# %% [markdown]
# ## Oppgave 1
# Tegn 100 tilfeldige punkter, der både _x_- og _y_-verdiene ligger i intervallet $[0,100>$.
#
# <details>
#     <summary style="color:green;">🛈 Klikk her for et hint</summary>
#     Vi trekker et tilfeldig heltall med funksjonen <code>randint(start,slutt)</code>.
#     For å bruke denne funksjonen må du importere biblioteket <code>random</code>.
# </details>

# %%
import matplotlib.pyplot as plt
import random

# %% [markdown]
# Siden intervallene for _x_ og _y_ ifølge oppgaven inneholder 0 men ikke 100, må vi være obs på dette når vi trekker tall.
#
# I de to første alternativene under trekkes tall i ℕ₀.

# %% [markdown]
# ### Alternativ 1

# %%
x_liste = []
y_liste = []

punkt = 0
while punkt < 100:
    x_liste.append( random.randint(0,99) )
    y_liste.append( random.randint(0,99) )
  
    punkt += 1

plt.plot(x_liste, y_liste, "o")    
plt.show()

# %% [markdown]
# ### Alternativ 2

# %%
punkt = 0
while punkt < 100:
    x_liste = [ random.randint(0,99) ]
    y_liste = [ random.randint(0,99) ]
    
    plt.plot(x_liste, y_liste, "o")
    punkt += 1
    
plt.show()

# %% [markdown]
# ### Alternativ 3
# Her trekker vi først et tilfeldig tall i intervallet $[0,1>$, og multipliserer med 100.
#
# Dette gjør at vi får koordinater i ℝ fra og med 0 til men ikke med 100.
#
# 🤔 Hvilke andre endringer er gjort?

# %%
punkt = 0
while punkt < 100:
    plt.plot( [ random.random() * 100 ], [ random.random() * 100 ], "s")
    punkt += 1
    
plt.show()

# %% [markdown]
# ## Oppgave 2
# Tegn 500 tilfeldige linjer. Hver linje skal trekkes mellom to punkter, der _x_-verdien skal ligge i intervallet $[0, 320>$ og _y_-verdien skal ligge i intervallet $[0,200>$.
#
#
# <details>
#     <summary style="color:green;">🛈 Klikk her for et hint</summary>
#     Her må du tegne en og en linje inne i en løkke.
# </details>

# %% [markdown]
# ### Alternativ 1

# %%
linje = 0
while linje < 500:
    x_liste = [ random.randint(0,319), random.randint(0,319) ]
    y_liste = [ random.randint(0,199), random.randint(0,199) ]
    
    plt.plot(x_liste, y_liste, "-")
    linje += 1
    
plt.show()

# %% [markdown]
# ### Alternativ 2
#
# 🤔 Hvilke andre endringer er gjort?

# %%
linje = 0
while linje < 500:
    x_liste = [ random.random() * 320, random.random() * 320 ]
    y_liste = [ random.random() * 200, random.random() * 200 ]
    
    plt.plot(x_liste, y_liste, ":")
    linje += 1
    
plt.show()
